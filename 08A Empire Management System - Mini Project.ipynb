# %% [markdown]
# ## Mini Project -7

# %% [markdown]
# # Empire Management System
# Store: Soldiers, Citizens, Gold, Food, Iterator
#
# → Soldiers ---> Generator
#
# → Strong soldiers only ---> Decorator
#
# → King Permission Required ---> Context Manager
#
# → Save kingdom
#
# Features: Manage citizens, Recruit soldiers, Collect taxes, Food storage, Gold treasury, Army reports, Save/Load data
#
# Concepts Used:
#
# Iterator → View citizens/soldiers one by one;
#
# Generator → Yield only active soldiers or wealthy citizens;
#
# Decorator → Admin/King authorization + activity logs;
#
# Context Manager → Save and load empire data

# %% [markdown]
# #### We will build it in this order:
# Step 1: Create modules (Empire.py, Main.py)
#
# Step 2: Empire class + data storage
#
# Step 3: Citizen management
#
# Step 4: Soldier recruitment
#
# Step 5: Iterator
#
# Step 6: Generator
#
# Step 7: Decorator
#
# Step 8: Context Manager
#
# Step 9: Final menu system

# %%
# %run Main.py
# Out:
# Empire Name: Vijayanagar
# Citizens: []
# Soldiers: []
# Gold: 1000
# Food: 500

# %%
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
#
# Citizens:
# ['Krishna', 'Arjun', 'Ravi']

# %%
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Main.py:9
#       6 vijayanagar.add_citizen("Ravi")
#       7 # Soldiers
#       8 vijayanagar.recruit_soldier(
# ----> 9     {
#      10         "name": "Veer",
#      11         "attack": 90,
#      12         "health": 100
#      13     }
#      14 )
#      15 vijayanagar.recruit_soldier(
#      16     {
#      17         "name": "Raj",
#    (...)
#      20     }
#      21 )
#      23 # Iterator
#
# TypeError: Empire.recruit_soldier() takes 2 positional arguments but 4 were given

# %% [markdown]
# #### Error Fix
#
# TypeError occurred because `recruit_soldier()` method and function call had different formats.
#
# Fixed by matching the method arguments and restarting the kernel to reload the updated module.

# %%
import Empire
print(Empire.__file__)
# Out:
# C:\Users\SANJANA\Empire.py

# %%
import importlib
import Empire
importlib.reload(Empire)
# Out:
# <module 'Empire' from 'C:\\Users\\SANJANA\\Empire.py'>

# %%
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# Veer joined the army!
# Raj joined the army!
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}

# %%
# Step 5 - Iterator
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# Veer joined the army!
# Raj joined the army!
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}
#
# Citizens:
# Krishna
# Arjun
# Ravi
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}

# %%
# Check methods
print([x for x in dir(Empire) if "iterator" in x])
# Out:
# ['citizen_iterator', 'soldier_iterator']

# %%
# Step 5 - Gebnerator
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# Veer joined the army!
# Raj joined the army!
#
# Citizens:
# Krishna
# Arjun
# Ravi
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}
#
# Strong Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}

# %%
# Step 6 - Decorator
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# Veer joined the army!
# Raj joined the army!
#
# Citizens:
# Krishna
# Arjun
# Ravi
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}
#
# Strong Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
#
# Tax Collection:
# Enter King Password:  king123
# Permission Granted!
# 500 gold collected!

# %%
# Step 7 - Activity Loger
print("\nTax Collection:")
vijayanagar.collect_tax(500)
# Out:
# Tax Collection:
# Enter King Password:  king123
# Permission Granted!
# 500 gold collected!

# %%
# Step8 - Context Manager
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# Veer joined the army!
# Raj joined the army!
#
# Citizens:
# Krishna
# Arjun
# Ravi
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}
#
# Strong Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
#
# Tax Collection:
# Enter King Password:  king123
# Permission Granted!
# Activity Log: collect_tax executed.
# 500 gold collected!
#
# Saving Empire...
# Opening Empire Save File...
# Managing the Empire...
# Empire Saved Successfully!

# %%
# Step 9: Final Feature – Empire Report
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# Veer joined the army!
# Raj joined the army!
#
# Citizens:
# Krishna
# Arjun
# Ravi
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}
#
# Strong Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
#
# Tax Collection:
# Enter King Password:  king123
# Permission Granted!
# Activity Log: collect_tax executed.
# 500 gold collected!
#
# Food Storage:
# 300 food added!
#
# ===== Gold Treasury =====
# Gold: 1500
#
# ===== Army Report =====
# Total Soldiers: 2
# Name: Veer | Attack: 90 | Health: 100 | Active: True
# Name: Raj | Attack: 60 | Health: 80 | Active: True
#
# Saving Empire...
# Opening Empire Save File...
# Managing the Empire...
# Empire Saved Successfully!

# %%
from Empire import Empire
print([name for name in dir(Empire) if not name.startswith("__")])
# Out:
# ['add_citizen', 'add_food', 'army_report', 'citizen_iterator', 'collect_tax', 'recruit_soldier', 'soldier_iterator', 'treasury']

# %%
import Empire
print(Empire.__file__)
# Out:
# C:\Users\SANJANA\Empire.py

# %%
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# Veer joined the army!
# Raj joined the army!
#
# Citizens:
# Krishna
# Arjun
# Ravi
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}
#
# Strong Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
#
# Tax Collection:
# Enter King Password:  king123
# Permission Granted!
# Activity Log: collect_tax executed.
# 500 gold collected!
#
# Food Storage:
# 300 food added!
#
# ===== Gold Treasury =====
# Gold: 1500
#
# ===== Army Report =====
# Total Soldiers: 2
# Name: Veer | Attack: 90 | Health: 100 | Active: True
# Name: Raj | Attack: 60 | Health: 80 | Active: True
#
# Saving Empire...
# Opening Empire Save File...
# Managing the Empire...
# Empire Saved Successfully!

# %%
# Step 10: Load Empire Data + Final Touch
# %run Main.py
# Out:
# Krishna joined the empire!
# Arjun joined the empire!
# Ravi joined the empire!
# Veer joined the army!
# Raj joined the army!
#
# Citizens:
# Krishna
# Arjun
# Ravi
#
# Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
# {'name': 'Raj', 'attack': 60, 'health': 80, 'active': True}
#
# Strong Soldiers:
# {'name': 'Veer', 'attack': 90, 'health': 100, 'active': True}
#
# Tax Collection:
# Enter King Password:  king123
# Permission Granted!
# Activity Log: collect_tax executed.
# 500 gold collected!
#
# Food Storage:
# 300 food added!
#
# ===== Gold Treasury =====
# Gold: 1500
#
# ===== Army Report =====
# Total Soldiers: 2
# Name: Veer | Attack: 90 | Health: 100 | Active: True
# Name: Raj | Attack: 60 | Health: 80 | Active: True
#
# Saving Empire...
# Opening Empire Save File...
# Managing the Empire...
# Empire Saved Successfully!
#
# Loading Empire...
#
# ===== Loaded Empire Data =====
# Empire: Vijayanagar
# Gold: 1500
# Food: 800
# ...
