# %% [markdown]
# ## Mini project 5

# %% [markdown]
# # Fortune Cookie Generator
#
# Store 100 quotes.
#
# Every run: Today's Fortune

# %%
# Create Quotes file
file = open("quote.txt", "w")
file.close()
print("File created successfully.")
# Adding the quotes to the file
file = open("quote.txt", "w")
file.write("Success follows consistent effort.\n")
file.write("Believe in yourself.\n")
file.write("Every day is a new beginning.\n")
file.write("Dream big and work hard.\n")
file.write("Small steps lead to big success.\n")
file.write("Stay Positive.\n")
file.write("Hard work beats talent.\n")
file.write("Learning never stops.\n")
file.write("Be kind to everyone.\n")
file.write("Never Give Up.\n")
file.write("Your future is created today.\n")
file.write("Confidence brings success.\n")
file.write("Patience is power.\n")
file.write("Keep moving forward.\n")
file.write("Mistakes help you learn.\n")
file.write("Challenges make you stronger.\n")
file.write("Believe you can.\n")
file.write("Great things take time.\n")
file.write("Stay focused.\n")
file.write("Keep smiling.\n")
file.close()
print("Data written successfully.")
# Out:
# File created successfully.
# Data written successfully.

# %%
# Fortune Cookie Generator
import random
file = open("quote.txt", "r")
quotes = file.readlines()
file.close()
fortune = random.choice(quotes)
print("Today's Fortune")
print("-----------------------")
print(fortune.strip())
# Out:
# Today's Fortune
# -----------------------
# Mistakes help you learn.

# %% [markdown]
# -----

# %%
# Fortune Cookie Generator - Method 2
import random
import os
if not os.path.exists("fortune_cookie.txt"):
    file = open("fortune_cookie.txt", "w")
    file.write("Your attitude shapes your future.\n")
    file.write("Be fearless in chasing dreams.\n")
    file.write("Every effort counts.\n")
    file.write("Good things take patience.\n")
    file.write("Hard work always pays off.\n")
    file.close()
file = open("fortune_cookie.txt", "r")
fortunes = file.readlines()
file.close()
print("\nToday's Fortune\n")
print(random.choice(fortunes).strip())
# Out:
# Today's Fortune
#
# Hard work always pays off.
